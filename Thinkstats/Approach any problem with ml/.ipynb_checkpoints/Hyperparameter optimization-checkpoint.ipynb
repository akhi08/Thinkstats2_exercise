# %% [raw]
# RandomForestClassifier(
# n_estimators=100,
# criterion='gini',
# max_depth=None,
# min_samples_split=2,
# min_samples_leaf=1,
# min_weight_fraction_leaf=0.0,
# max_features='auto',
# max_leaf_nodes=None,
# min_impurity_decrease=0.0,
# min_impurity_split=None,
# bootstrap=True,
# oob_score=False,
# n_jobs=None,
# random_state=None,
# verbose=0,
# warm_start=False,
# class_weight=None,
# ccp_alpha=0.0,
# max_samples=None,
# )
#
# - There are nineteen parameters, and all the combinations of all these parameters for
# all the values they can assume are going to be infinite.
# - we specify a grid of parameters. A search over
# this grid to find the best combination of parameters is known as grid search.
# #rf_grid_search.py

# %%
import pandas as pd
# i÷
df = pd.read_csv("/Users/akhichoudhary/STATS/Thinkstats/Thinkstats2_exercise/Thinkstats/Approach any problem with ml/mnist_classifier/input/mobile data/train.csv")

# %%
import os
os.getcwd()
# Out:
# '/Users/akhichoudhary/STATS/Thinkstats/Thinkstats2_exercise/Thinkstats/Approach any problem with ml'
